# %%
import mlflow
# import tensorflow
import keras
import numpy as np
import pandas as pd

# %%
from hyperopt import STATUS_OK,Trials,fmin,hp, tpe
from mlflow.models import infer_signature
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

# %%
data=pd.read_csv("https://raw.githubusercontent.com/mlflow/mlflow/master/tests/datasets/winequality-white.csv",sep=";")
data
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    45.0                 170.0  1.00100  3.00       0.45
# 1                    14.0                 132.0  0.99400  3.30       0.49
# 2                    30.0                  97.0  0.99510  3.26       0.44
# 3                    47.0                 186.0  0.99560  3.19       0.40
# 4                    47.0                 186.0  0.99560  3.19       0.40
# ...                   ...                   ...      ...   ...        ...
# 4893                 24.0                  92.0  0.99114  3.27       0.50
# 4894                 57.0                 168.0  0.99490  3.15       0.46
# 4895                 30.0                 111.0  0.99254  2.99       0.46
# 4896                 20.0                 110.0  0.98869  3.34       0.38
# 4897                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality
# 0         8.8        6
# 1         9.5        6
# 2        10.1        6
# 3         9.9        6
# 4         9.9        6
# ...       ...      ...
# 4893     11.2        6
# 4894      9.6        5
# 4895      9.4        6
# 4896     12.8        7
# 4897     11.8        6
#
# [4898 rows x 12 columns]

# %%
# split the dta into training validation and test set
train,test=train_test_split(data,test_size=.25,random_state=42)

# %%
train
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 2835            6.3              0.25         0.22            3.30      0.048
# 1157            7.8              0.30         0.29           16.85      0.054
# 744             7.4              0.38         0.27            7.50      0.041
# 1448            7.4              0.16         0.49            1.20      0.055
# 3338            7.2              0.27         0.28           15.20      0.046
# ...             ...               ...          ...             ...        ...
# 4426            6.2              0.21         0.52            6.50      0.047
# 466             7.0              0.14         0.32            9.00      0.039
# 3092            7.6              0.27         0.52            3.20      0.043
# 3772            6.3              0.24         0.29           13.70      0.035
# 860             8.1              0.27         0.35            1.70      0.030
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 2835                 41.0                 161.0  0.99256  3.16       0.50
# 1157                 23.0                 135.0  0.99980  3.16       0.38
# 744                  24.0                 160.0  0.99535  3.17       0.43
# 1448                 18.0                 150.0  0.99170  3.23       0.47
# 3338                  6.0                  41.0  0.99665  3.17       0.39
# ...                   ...                   ...      ...   ...        ...
# 4426                 28.0                 123.0  0.99418  3.22       0.49
# 466                  54.0                 141.0  0.99560  3.22       0.43
# 3092                 28.0                 152.0  0.99129  3.02       0.53
# 3772                 53.0                 134.0  0.99567  3.17       0.38
# 860                  38.0                 103.0  0.99255  3.22       0.63
#
#       alcohol  quality
# 2835     10.5        6
# 1157      9.0        6
# 744      10.0        5
# 1448     11.2        6
# 3338     10.9        6
# ...       ...      ...
# 4426      9.9        6
# 466       9.4        6
# 3092     11.4        6
# 3772     10.6        6
# 860      10.4        8
#
# [3673 rows x 12 columns]

# %%
X=train.drop(['quality'],axis=1).values
y=train[['quality']].values.ravel()
# validation
X_train,Valid_X,y_train,valid_y=train_test_split(X,y,test_size=.20,random_state=42)

# test data
X_test=test.drop(['quality'],axis=1).values
y_test=test[['quality']].values.ravel()

signature=infer_signature(X_train,y_train)

# %%
np.mean(X_train,axis=0)
# Out:
# array([6.86621852e+00, 2.80377808e-01, 3.32597005e-01, 6.42164738e+00,
#        4.55513955e-02, 3.53556841e+01, 1.38792376e+02, 9.94074221e-01,
#        3.18919333e+00, 4.88396869e-01, 1.05005673e+01])

# %%
### ANN Model

def train_model(params,epochs,train_x,train_y,valid_x,valid_y,test_x,test_y):

    ## Define model architecture
    mean=np.mean(train_x,axis=0)
    var=np.var(train_x,axis=0)

    model=keras.Sequential(
        [
            keras.Input([train_x.shape[1]]),
            keras.layers.Normalization(mean=mean,variance=var),
            keras.layers.Dense(64,activation='relu'),
            keras.layers.Dense(1)

        ]
    )

    ## compile the model
    model.compile(optimizer=keras.optimizers.SGD(
        learning_rate=params["lr"],momentum=params["momentum"]
    ),
    loss="mean_squared_error",
    metrics=[keras.metrics.RootMeanSquaredError()]
    )

    ## Train the ANN model with lr and momentum params wwith MLFLOW tracking
    with mlflow.start_run(nested=True):
        model.fit(train_x,train_y,validation_data=(valid_x,valid_y),
                  epochs=epochs,
                  batch_size=64)
        
        ## Evaluate the model
        eval_result=model.evaluate(valid_x,valid_y,batch_size=64)

        eval_rmse=eval_result[1]

        ## Log the parameters and results
        mlflow.log_params(params)
        mlflow.log_metric("eval_rmse",eval_rmse)

        ## log the model

        mlflow.tensorflow.log_model(model,"model",signature=signature)

        return {"loss": eval_rmse, "status": STATUS_OK, "model": model}

# %%
def objective(params):
    # MLflow will track the parameters and results for each run
    result = train_model(
        params,
        epochs=3,
        train_x=X_train,
        train_y=y_train,
        valid_x=Valid_X,
        valid_y=valid_y,
        test_x=X_test,
        test_y=y_test,
    )
    return result

# %%
space={
    "lr":hp.loguniform("lr",np.log(1e-5),np.log(1e-1)),
    "momentum":hp.uniform("momentum",0.0,1.0)

}

# %%
mlflow.set_experiment("wine-quality")
with mlflow.start_run():
    # Conduct the hyperparameter search using Hyperopt
    trials=Trials()
    best=fmin(
        fn=objective,
        space=space,
        algo=tpe.suggest,
        max_evals=4,
        trials=trials
    )

    # Fetch the details of the best run
    best_run = sorted(trials.results, key=lambda x: x["loss"])[0]

    # Log the best parameters, loss, and model
    mlflow.log_params(best)
    mlflow.log_metric("eval_rmse", best_run["loss"])
    mlflow.tensorflow.log_model(best_run["model"], "model", signature=signature)

    # Print out the best parameters and corresponding loss
    print(f"Best parameters: {best}")
    print(f"Best eval rmse: {best_run['loss']}")
# Out:
# 2025/01/06 16:15:23 INFO mlflow.tracking.fluent: Experiment with name 'wine-quality' does not exist. Creating a new experiment.
# Epoch 1/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 1:36 2s/step - loss: 35.8234 - root_mean_squared_error: 5.9853
#  9/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 33.9259 - root_mean_squared_error: 5.8239
# 22/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 30.5541 - root_mean_squared_error: 5.5197
# 38/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 26.6977 - root_mean_squared_error: 5.1413
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 24.8698 - root_mean_squared_error: 4.9497 - val_loss: 4.1761 - val_root_mean_squared_error: 2.0436
#
# Epoch 2/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - loss: 4.6453 - root_mean_squared_error: 2.1553
# 15/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6860 - root_mean_squared_error: 1.9174
# 29/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.3771 - root_mean_squared_error: 1.8343
# 41/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.1974 - root_mean_squared_error: 1.7839
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.1223 - root_mean_squared_error: 1.7623 - val_loss: 2.0260 - val_root_mean_squared_error: 1.4234
#
# Epoch 3/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - loss: 1.8835 - root_mean_squared_error: 1.3724
# 15/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0291 - root_mean_squared_error: 1.4238
# 29/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9777 - root_mean_squared_error: 1.4058
# 39/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9593 - root_mean_squared_error: 1.3993
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.9422 - root_mean_squared_error: 1.3932 - val_loss: 1.7936 - val_root_mean_squared_error: 1.3393
#
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 1.4523 - root_mean_squared_error: 1.2051
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.7991 - root_mean_squared_error: 1.3403
#
# Epoch 1/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 40s 898ms/step - loss: 32.0934 - root_mean_squared_error: 5.6651
# 12/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 32.4911 - root_mean_squared_error: 5.7001
# 25/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 32.4977 - root_mean_squared_error: 5.7007
# 40/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 32.3923 - root_mean_squared_error: 5.6914
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 32.3189 - root_mean_squared_error: 5.6849 - val_loss: 30.6808 - val_root_mean_squared_error: 5.5390
#
# Epoch 2/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - loss: 30.2421 - root_mean_squared_error: 5.4993
#  9/46 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 30.1194 - root_mean_squared_error: 5.4881
# 20/46 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 30.1511 - root_mean_squared_error: 5.4910
# 30/46 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 30.1056 - root_mean_squared_error: 5.4868
# 37/46 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 30.0536 - root_mean_squared_error: 5.4821
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 29.9686 - root_mean_squared_error: 5.4743 - val_loss: 28.4438 - val_root_mean_squared_error: 5.3333
#
# Epoch 3/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - loss: 29.2757 - root_mean_squared_error: 5.4107
# 16/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 28.9300 - root_mean_squared_error: 5.3786
# 31/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 28.5165 - root_mean_squared_error: 5.3399
# 45/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 28.2422 - root_mean_squared_error: 5.3140
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 28.2075 - root_mean_squared_error: 5.3108 - val_loss: 26.3662 - val_root_mean_squared_error: 5.1348
#
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 26.6010 - root_mean_squared_error: 5.1576
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 26.1758 - root_mean_squared_error: 5.1162
#
# Epoch 1/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 38s 851ms/step - loss: 31.2861 - root_mean_squared_error: 5.5934
# 16/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 31.1033 - root_mean_squared_error: 5.5769
# 31/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 30.9857 - root_mean_squared_error: 5.5664
# 44/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 30.8236 - root_mean_squared_error: 5.5518
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 30.7881 - root_mean_squared_error: 5.5486 - val_loss: 28.3868 - val_root_mean_squared_error: 5.3279
#
# Epoch 2/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - loss: 26.1229 - root_mean_squared_error: 5.1111
# 16/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 27.3165 - root_mean_squared_error: 5.2264
# 31/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 27.1874 - root_mean_squared_error: 5.2141
# 43/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 27.0454 - root_mean_squared_error: 5.2004
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 26.9999 - root_mean_squared_error: 5.1960 - val_loss: 24.8577 - val_root_mean_squared_error: 4.9858
#
# Epoch 3/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step - loss: 24.8633 - root_mean_squared_error: 4.9863
# 19/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 24.4308 - root_mean_squared_error: 4.9427
# 33/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 24.1812 - root_mean_squared_error: 4.9173
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 23.9549 - root_mean_squared_error: 4.8941
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 23.9392 - root_mean_squared_error: 4.8925 - val_loss: 21.7633 - val_root_mean_squared_error: 4.6651
#
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 22.4481 - root_mean_squared_error: 4.7379
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 21.7604 - root_mean_squared_error: 4.6647
#
# Epoch 1/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 37s 840ms/step - loss: 41.9137 - root_mean_squared_error: 6.4741
# 16/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 25.2563 - root_mean_squared_error: 4.9638
# 29/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 19.0794 - root_mean_squared_error: 4.2538
# 36/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 17.0080 - root_mean_squared_error: 3.9910
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 14.8361 - root_mean_squared_error: 3.6990
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 14.6577 - root_mean_squared_error: 3.6744 - val_loss: 1.5383 - val_root_mean_squared_error: 1.2403
#
# Epoch 2/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - loss: 1.2234 - root_mean_squared_error: 1.1061
# 15/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3319 - root_mean_squared_error: 1.1537
# 31/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2866 - root_mean_squared_error: 1.1339
# 42/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2791 - root_mean_squared_error: 1.1307
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.2763 - root_mean_squared_error: 1.1295 - val_loss: 1.1370 - val_root_mean_squared_error: 1.0663
#
# Epoch 3/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - loss: 1.0705 - root_mean_squared_error: 1.0347
# 15/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0157 - root_mean_squared_error: 1.0076
# 30/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0247 - root_mean_squared_error: 1.0121
# 45/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0196 - root_mean_squared_error: 1.0097
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0183 - root_mean_squared_error: 1.0090 - val_loss: 0.9466 - val_root_mean_squared_error: 0.9730
#
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.8261 - root_mean_squared_error: 0.9089
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9387 - root_mean_squared_error: 0.9684
#
# 100%|██████████| 4/4 [01:25<00:00, 21.48s/trial, best loss: 0.9729592800140381]
# Best parameters: {'lr': np.float64(0.009299996139128663), 'momentum': np.float64(0.09565542949762484)}
# Best eval rmse: 0.9729592800140381
